# %%
import base.plotting as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
reload(plt)
# Out:
# <module 'base.plotting' from 'base/plotting.pyc'>

# %%
plot = plt.plot_polar(pd.DataFrame(np.array([[1, 1, 1], [0.5, 1, 2]]).T), overplot=True, threshold = 1)
# Out:
# (1000,)
# (1000,)
