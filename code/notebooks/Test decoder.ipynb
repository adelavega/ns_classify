# %%
from neurosynth.analysis.decode import Decoder
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("../data/datasets/abs_60topics_filt_jul.pkl")
# %matplotlib inline

# %%
d = Decoder(dataset, method='roi')

# %%
res = d.decode('../results/perm_cluster/results/medial_fc_30_kmeans/kmeans_k3/cluster_labels.nii.gz')

# %%
res
# Out:
#          cluster_0  cluster_1  cluster_2
# topic0     -0.9809    -1.7775     1.6390
# topic1      0.3446     1.1068     1.5791
# topic10    -2.7853    -3.4875    -5.4660
# topic11    -0.3186    -1.9764     8.8975
# topic12    -3.2444    -2.8819    -3.0797
# topic13     5.8335     4.3859    -1.2998
# topic14    -3.0717    -4.2636     1.8380
# topic15    -1.4644    31.6869    -8.3750
# topic16    -0.8491    -3.2397     3.6363
# topic17    -7.5407    -5.0140    -5.3375
# topic18    -5.0025     1.2377    -3.6716
# topic19     0.9169    -0.4306    -3.6737
# topic2     -2.2342     4.8812    -3.4759
# topic20    -0.5921     4.2057    -3.6717
# topic21    -1.7337     1.4372    -2.9634
# topic22     4.6864     2.6306     1.3872
# topic23     2.2923    -3.9134    15.9532
# topic24    -4.9404     2.3262    -5.7134
# topic25    -0.2384    -0.2865    10.3331
# topic26     1.8531    -0.0533    -2.3351
# topic27     0.2097    -3.2937    -0.3343
# topic28    -6.3622    -3.4222    -5.2971
# ...

# %%
d.plot_polar(res, overplot=True)
# Out:
# <module 'matplotlib.pyplot' from '/Users/aleph4/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>
