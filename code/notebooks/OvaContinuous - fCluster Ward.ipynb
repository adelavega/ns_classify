# %%
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("../data/datasets/abs_60topics_filt_jul.pkl")

# %%
from IPython.html import widgets
# %load_ext rpy2.ipython
# %matplotlib inline

# %%
import numpy as np
from base import plotting
from base.classifiers import OnevsallClassifier, PairwiseClassifier, OnevsallContinuous
import base.classifiers.pairwise as pw
import base.classifiers.onevsall as oa
import glob
import pandas as pd
from ggplot import *
from base import tools
from scipy import stats
import itertools
import seaborn as sns
import mpld3
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pylab
import base.classifiers.pairwise as mc
from base.statistics import dcor
import re

# %%
mpld3.enable_notebook()

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(MASS)
# library(reshape2)
# Out:
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %% [markdown]
# # Overall results

# %%
clfs = [OnevsallContinuous.load(clf + "/classifier.pkl") for clf in glob.glob("../results/ward_f[0-9][0-9]_Ridge*cog*")]

# %%
plot_score = []
all_scores = []
for clfs in [clfs]:
    for clf in clfs:
        for n, score in enumerate(clf.class_score):
            all_scores.append([clf.mask_num, n, clf.n_features_orig, 'clf' , score])
        plot_score.append([clf.mask_num, clf.n_features_orig, 'clf' , clf.class_score.mean()])

# %%
plot_score = pd.DataFrame(plot_score, columns=['n_regions', 'n_topics', 'clf', 'r2'])
plot_score['n_regions'] = plot_score['n_regions'].apply(str)

all_scores = pd.DataFrame(all_scores, columns=['n_regions', 'region', 'n_topics', 'clf', 'r2'])
all_scores['n_regions'] = all_scores['n_regions'].apply(str)

# %%
from base.tools import region_n_vox
n_vox = []
for regions in clfs:
    n_vox = n_vox + list(itertools.izip(itertools.repeat(regions.mask_num), range(0, regions.mask_num), 
                                     list(region_n_vox(dataset, regions.mask_img))))
n_vox = pd.DataFrame(n_vox, columns=['n_regions', 'region', 'voxels'])
n_vox['n_regions'] = n_vox['n_regions'].apply(str)

# %%
all_scores = pd.merge(all_scores, n_vox)
# %Rpush all_scores

# %%
# %%R -w 500 -h 400
# ggplot(all_scores, aes(n_topics, r2, color=n_regions)) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=5) + stat_summary(fun.y=mean, geom='point', size=5, shape=1, color="black") + theme_bw()

# %%
# %%R -w 400 -h 400
# ggplot(subset(all_scores, n_topics==60), aes(n_regions, r2, color=n_regions)) + geom_point(position=position_jitter(width=0.005)) +
#  stat_summary(fun.y=mean, geom='point', size=5) + stat_summary(fun.y=mean, geom='point', size=5, shape=1, color="black") + theme_bw() + theme(legend.position='none')

# %%
np.sqrt(all_scores.r2.min())
# Out:
# 0.11533288034450646

# %%
all_scores.groupby(['n_regions', 'n_topics']).agg(np.mean)
# Out:
#                     region        r2       voxels
# n_regions n_topics
# 30        60          14.5  0.096941  7561.833333

# %%
all_scores.groupby('n_regions').describe()
# Out:
#                  n_topics         r2     region        voxels
# n_regions
# 30        count        30  30.000000  30.000000     30.000000
#           mean         60   0.096941  14.500000   7561.833333
#           std           0   0.045510   8.803408  12245.242744
#           min          60   0.013302   0.000000      0.000000
#           25%          60   0.065581   7.250000   2265.000000
#           50%          60   0.093232  14.500000   3838.000000
#           75%          60   0.132917  21.750000   6613.750000
#           max          60   0.213313  29.000000  65376.000000

# %%
# %%R -w 1000 -h 480 -u px
# ggplot(all_scores, aes(voxels, r2, color=factor(n_topics))) + geom_point(size = 2) + theme_bw() + stat_smooth(method=rlm, se=F)

# %%
num_regions = 30
num_topics =60

# %%
o_clf = [clf for clf in clfs if (clf.mask_num == num_regions) & (clf.n_features_orig == num_topics)][0]

# %%
o_clf.mask_img
# Out:
# '../results/cluster_3mm_ward/ClusterImages/Cluster_k30.nii.gz'

# %%
o_clf.class_score.mean()
# Out:
# 0.096940615434231769

# %%
tools.make_mask_map(o_clf.class_score, o_clf.mask_img, '../results/ward_f' + str(num_regions) + '_Ridge_abs_topics' + str(num_topics) + '_filt/class_scores')

# %%
dataset.masker.mask(o_clf.mask_img).dtype
# Out:
# dtype('<f8')

# %% [markdown]
# ### Discriminability by base rate

# %%
# Set region and classifier for following analyses
base_rates = tools.region_vox_baserates(dataset, o_clf.mask_img)

# %%
acc = all_scores[(all_scores['n_topics'] == num_topics) & (all_scores['n_regions'] == str(num_regions))].copy()

acc = pd.merge(base_rates, acc)
mean_acc = acc.groupby(['region']).agg(np.mean).reset_index()

# %%
mean_br = acc.groupby(['region']).agg(np.mean).reset_index()
mean_br_plot = mean_br.rename(columns = {'base_rate':'Activation base rate (% studies active)', 'r2': "R-squared"})
br_auc_oplot = sns.lmplot('Activation base rate (% studies active)', 'R-squared', mean_br_plot, ci=None)
tooltip = mpld3.plugins.PointLabelTooltip(br_auc_oplot.axes[0][0].collections[0], labels=list(mean_br.region))
fig = plt.gcf()
mpld3.plugins.connect(fig, tooltip)
# %Rpush mean_br

# %% [markdown]
# ## Feature importance analysis

# %%
word_keys = pd.read_csv("../data/unprocessed/abstract_topics_filtered/topic_sets/top_words_" + str(num_topics) + ".csv")
word_keys['top_2'] = word_keys.top_words.apply(lambda x: x.split(' ')[0] + ', ' + x.split(' ')[1])
word_keys['top_words'] = word_keys.top_words.apply(lambda x: x.split(' ')[0] + ', ' + x.split(' ')[1] + ', ' + x.split(' ')[2])

# %%
o_fi = pd.DataFrame(o_clf.feature_importances)

# Melt feature importances, and add top_words for each feeature
o_fi['region'] = range(1, o_fi.shape[0] + 1)
o_fis_melt = pd.melt(o_fi, var_name='topic_order', value_name='importance', id_vars=['region'])

word_keys = pd.merge(pd.DataFrame(np.array([range(0, o_clf.feature_importances.shape[1]), o_clf.feature_names]).T, columns=['topic_order', 'topic_name']), word_keys)
word_keys.topic_order = word_keys.topic_order.astype('int')

o_fis_melt= pd.merge(o_fis_melt, word_keys)
o_fis_melt['abs_imp'] = np.abs(o_fis_melt['importance'])

o_fis_melt = pd.merge(o_fis_melt, mean_acc)
# %Rpush o_fis_melt

# %%
categories = np.unique(o_fis_melt['topic_name'])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))
o_fis_melt["Color"] = o_fis_melt['topic_name'].apply(lambda x: colordict[x])

pylab.rcParams['figure.figsize'] = 10, 5  # that's default image size for this interactive session
sns.set_style("white")
scatter = plt.scatter(o_fis_melt.r2, o_fis_melt.importance, c=o_fis_melt.Color, cmap=cm.Set1, s=50, alpha=0.8)
fig = plt.gcf()
tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=list(zip(o_fis_melt.region.values, o_fis_melt.top_words.values)))
mpld3.plugins.connect(fig, tooltip)

# %% [markdown]
# ## Bar plots

# %%
zscore = lambda x: (x - x.mean()) / x.std()
o_fis_melt['importance_z'] = o_fis_melt.groupby('region')['importance'].apply(zscore)

# %%
vmpfc_30 = np.array([10, 13, 3, 8, 11, 17]) - 1
vmpfc_40 = np.array([34, 7, 8, 17, 11, 6, 13, 40, 26, 15]) - 1
# 10 = dlpfc cluster
selected_regions = o_fis_melt[np.in1d(o_fis_melt.region,vmpfc_30) ]

vmpfc_30_name = ['SMA', 'pre-SMA', 'pMCC', 'aMCC', 'ACC/OFC', 'aMPFC']
oldNewMap = {16: 'SMA', 10: 'pre-SMA', 7: 'pMCC', 2: 'aMCC', 9: 'aMPFC', 12: 'ACC/OFC'}
selected_regions['region_names'] = selected_regions['region'].map(oldNewMap)

# %%
plt.figure(figsize=(9, 8.5))
sns.heatmap(pd.pivot_table(selected_regions, values='importance', index=['top_2'], columns=['region_names']), robust=True)

# %%
plt.figure(figsize=(9, 8.5))

sns.heatmap(pd.pivot_table(selected_regions, values='importance', index=['top_2'], columns=['region_names']))

# %%
# ?sns.heatmap

# %%
from base import img_tools

# %%
# Top_3
sel_topics = selected_regions[selected_regions.groupby('region').rank(ascending=False).importance < 4]
top_n = selected_regions[np.in1d(selected_regions.topic_name, sel_topics.topic_name) ]

# %Rpush top_n
# %Rpush vmpfc_30
# %Rpush vmpfc_30_name

# %%
plt.figure(figsize=(7.8, 5))
sns.heatmap(pd.pivot_table(top_n, values='importance', index=['top_words'], columns=['region_names']))

# %%
# %%R
# top_n$region <- factor(top_n$region, levels = rev(vmpfc_30))
# top_n$region_names <- factor(top_n$region_names, levels = vmpfc_30_name)
#
# vmpfc_30_name
# Out:
# [1] "SMA"     "pre-SMA" "pMCC"    "aMCC"    "ACC/OFC" "aMPFC"

# %%
# %%R -w 550 -h 750
# library(ggplot2)
#
# vmpfc_30_colors = c("#0C30FF", "#00760D" , "#CC3E4D", "#E59321", "#79B9DC", "#DCD813")
#
# ggplot(top_n, aes(top_words, importance, fill=factor(region_names))) + geom_bar(stat='identity') +
# theme_bw() + theme(axis.text.x=element_text(angle = 45, hjust=1), legend.position='none') +
# facet_grid(region_names~.) + ylab("Topic weight") + xlab("Topics (top words)") +
# scale_fill_manual(values = rev(vmpfc_30_colors))
# # theme(strip.text.y = element_blank(), strip.background = element_blank())
#
#
# # ggsave("../reports/vmpfc_comps/bar_top2_30.pdf")

# %%
tools.make_mask_map(selected_regions.groupby('region').mean().r2, o_clf.mask_img, '../results/ward_f30_Ridge_abs_topics60_filt/class_score_vmpfc.nii.gz', index=vmpfc_30 - 1)

# %% [markdown]
# #Multivarate plots

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import make_scorer
from base.mv import calc_mv
from sklearn.metrics import auc
vmpfc_30.sort()
vmpfc_40.sort()

# %%
all_reg = np.arange(0, o_clf.feature_importances.shape[0] + 2)
rev_index = all_reg[np.invert(np.in1d(all_reg, vmpfc_30 +1))]
img_tools.remove_value(o_clf.mask_img, rev_index, '../results/cluster_3mm_ward/ClusterImages/k30_vmpfc.nii.gz')

# %%
mv_results = calc_mv(o_clf, make_scorer(explained_variance_score), regions=vmpfc_30-1, processes=7)
mv_results.region = mv_results.region + 1
# Out:
# [#] 16%
# [###] 33%
# [#####] 50%
# [######] 66%
# [########] 83%
# [##########] 100%

# %%
unit_norm = lambda x: (x / x.max())
mv_results['score_unit'] = mv_results.groupby('region')['score'].apply(unit_norm)

# %Rpush mv_results

# %%
vmpfc_30
# Out:
# array([ 2,  7,  9, 10, 12, 16])

# %%
# %%R
# levels(factor(mv_results$region))
# Out:
# [1] "2"  "7"  "9"  "10" "12" "16"

# %%
# %%R -w 600 -h 500
#
# mv_results$region <- factor(mv_results$region, levels = rev(vmpfc_30))
#
# library(ggplot2)
# ggplot(mv_results, aes(num_features, score_unit, color=factor(region))) + theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2))  + stat_summary(fun.y=mean, geom="line", size=1) +
# scale_color_manual(values = rev(vmpfc_30_colors), name = "Region")
#
# ggsave("../reports/vmpfc_comps/mv_ev_unit_complete.pdf")
# Out:
# Saving 8.33 x 6.94 in image

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results, aes(num_features, score, color=factor(region))) + theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2))  + stat_summary(fun.y=mean, geom="line", size=1) +
# scale_color_manual(values = rev(vmpfc_30_colors), name = "Region") +
# geom_vline(xintercept=1, linetype=5, alpha=0.7) + geom_vline(xintercept=22, linetype=5, alpha=0.7)
#
# # ggsave("../reports/vmpfc_comps/mv_ev_abs_complete.pdf")

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results, aes(num_features, score_unit, color=factor(region))) + theme_bw() + ylab("Relative explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2)) + coord_cartesian(xlim = c(0, 20)) + stat_summary(fun.y=mean, geom="line", size=1) +
# scale_color_manual(values = rev(vmpfc_30_colors), name = "Region")
# # + geom_vline(xintercept=5, linetype=5, alpha=0.7)
#
# # ggsave("../reports/vmpfc_comps/mv_ev_abs_25.pdf")

# %%
mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))
# Out:
# region
# 2         27.402160
# 7         30.891473
# 9         29.591810
# 10        28.863852
# 12        27.641852
# 16        31.661193
# dtype: float64

# %%
stats.pearsonr(mean_br[np.in1d(mean_br.region, vmpfc_30)].base_rate, mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-49a71288150a> in <module>()
# ----> 1 stats.pearsonr(mean_br[np.in1d(mean_br.region, vmpfc_30)].base_rate, mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])))
#
# /usr/local/lib/python2.7/site-packages/scipy/stats/stats.pyc in pearsonr(x, y)
#    2432     my = y.mean()
#    2433     xm, ym = x-mx, y-my
# -> 2434     r_num = np.add.reduce(xm * ym)
#    2435     r_den = np.sqrt(ss(xm) * ss(ym))
#    2436     r = r_num / r_den
#
# ValueError: operands could not be broadcast together with shapes (5,) (6,)

# %%
mv_results.groupby('region').apply(lambda x: x.score.max() - x[x.num_features == 1].score )

# %%
stats.pearsonr(mv_results.groupby('region').apply(lambda x: x.score.max() - x[x.num_features == 2].score ), mv_results.query('num_features <= 22').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])))

# %%
stats.pearsonr(mv_results.groupby('region').apply(lambda x: x.score.max() - x[x.num_features == 1].score ), mean_br[np.in1d(mean_br.region, vmpfc_30)].base_rate)

# %%
mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))

# %%
mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))

# %%
mv_results.query('num_features <= 10').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))

# %%
stats.pearsonr(selected_regions.groupby('region').mean().base_rate, mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])))

# %%
sns.regplot(selected_regions.groupby('region').mean().base_rate, mv_results.groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])))

# %%
tools.make_mask_map(mv_results.query('num_features <= 10').groupby('region').apply(
    lambda x: auc(x['num_features'], x['score_unit'])).values, o_clf.mask_img, 
        '../results/ward_f' + str(num_regions) + '_Ridge_abs_topics' + str(num_topics) + '_filt/mv_auc_10f_vmpfc', index=vmpfc_30 - 1)

# %%
tools.make_mask_map(selected_regions.groupby('region').mean().base_rate.values, o_clf.mask_img,
                    '../results/ward_f' + str(num_regions) + '_Ridge_abs_topics' + str(num_topics) + '_filt/base_rate_vmpfc', index=vmpfc_30 - 1)

# %%
mv_results['score_log_t100'] = np.log10(mv_results.score*100 + 1)

# %%
tools.make_mask_map(mv_results[mv_results.num_features == 1].score_log_t100, o_clf.mask_img, '../results/ward_f30_Ridge_cog_topics/mv_1_score_log_t100')
tools.make_mask_map(mv_results[mv_results.num_features == 34].score_log_t100, o_clf.mask_img, '../results/ward_f30_Ridge_cog_topics/mv_max_34_score_log_t100')

# %%
mv_results.query('num_features <= 10').groupby('region').apply(
    lambda x: auc(x['num_features'], x['score_unit'])).values
# Out:
# array([ 5.1746654 ,  8.09933609,  7.19352177,  6.17792642,  5.68537718,
#         8.73873721])

# %%
def cum_auc(df):
    results = []
    for i in range(3, df['num_features'].max() + 2):
        new_df = df.query('num_features < ' +str(i))
        results.append(auc(new_df['num_features'], new_df['score_unit']))
        
    results = pd.DataFrame(results).reset_index(level=0)   
    results.columns = ['num_features', 'cum_auc']
    results.num_features = results.num_features +2
    return results

# %%
test_df = mv_results[mv_results['region'] == 2]

# %%
cumauc_mv_vmpfc = mv_results.groupby('region').apply(lambda x: cum_auc(x))

# %%
cumauc_mv_vmpfc.reset_index(level=0, inplace=True)
# %Rpush cumauc_mv_vmpfc

# %% [markdown]
# ### All regions

# %%
mv_results_all = calc_mv(o_clf, make_scorer(explained_variance_score), processes=7)
# Out:
# [] 3%
# [] 6%
# [#] 10%
# [#] 13%
# [#] 16%
# [##] 20%
# [##] 23%
# [##] 26%
# [###] 30%
# [###] 33%
# [###] 36%
# [####] 40%
# [####] 43%
# [####] 46%
# [#####] 50%
# [#####] 53%
# [#####] 56%
# [######] 60%
# [######] 63%
# [######] 66%
# [#######] 70%
# [#######] 73%
# [#######] 76%
# [########] 80%
# [########] 83%
# [########] 86%
# [#########] 90%
# [#########] 93%
# [#########] 96%
# [##########] 100%

# %%
mv_results_all['score_unit'] = mv_results_all.groupby('region')['score'].apply(unit_norm)
mv_results_all['vmpfc'] = np.in1d(mv_results_all.region, vmpfc_30-1)
# %Rpush mv_results_all

# %%
mv_auc = mv_results_all.query('num_features < 6').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])).values

# %%
tools.make_mask_map(mv_auc, o_clf.mask_img, '../results/ward_f' + str(num_regions) + '_Ridge_abs_topics' + str(num_topics) + '_filt/mv_auc_5f')

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results_all, aes(num_features, score_unit, color=factor(region))) + stat_summary(fun.y=mean, geom="point", size=1) + theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2))  + stat_summary(fun.y=mean, geom="line", size=0.8)

# %%
# %%R -w 600 -h 500
# ggplot(mv_results_all, aes(num_features, score, color=factor(region))) + stat_summary(fun.y=mean, geom="point", size=2) +
# theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2)) + coord_cartesian(xlim = c(0, 10)) +
# stat_summary(fun.y=mean, geom="line", size=1)

# %%
stats.pearsonr(o_fis_melt.groupby('region').mean().base_rate, mv_results_all.query('num_features <= 10').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-8ceea49451ea> in <module>()
# ----> 1 stats.pearsonr(o_fis_melt.groupby('region').mean().base_rate, mv_results_all.query('num_features <= 10').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))[1:])
#
# /usr/local/lib/python2.7/site-packages/scipy/stats/stats.pyc in pearsonr(x, y)
#    2432     my = y.mean()
#    2433     xm, ym = x-mx, y-my
# -> 2434     r_num = np.add.reduce(xm * ym)
#    2435     r_den = np.sqrt(ss(xm) * ss(ym))
#    2436     r = r_num / r_den
#
# ValueError: operands could not be broadcast together with shapes (28,) (29,)

# %%
 mv_results_all.groupby('region').mean()['vmpfc'][1:]

# %%
freq_complex = pd.DataFrame(np.array([o_fis_melt.groupby('region').mean()['base_rate'],mv_results_all.query('num_features <= 10').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit']))[1: ],
                       mv_results_all.groupby('region').mean()['vmpfc'][1:]]).T, columns=['Activation Frequency', 'Functional complexity (AUC at 10 topics)', 'mPFC'])

# %%
mpld3.disable_notebook()
sns.set_context('talk')
sns.lmplot('Activation Frequency', 'Functional complexity (AUC at 10 topics)', freq_complex)

# %%
# ?sns.lmplot

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results_all, aes(num_features, score_unit, color=factor(region))) + stat_summary(fun.y=mean, geom="point", size=2) + theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2), legend.position='none') + coord_cartesian(xlim = c(0, 10)) + stat_summary(fun.y=mean, geom="line", size=1)

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results_all, aes(num_features, score_unit, group=region, color=vmpfc, alpha=vmpfc)) + stat_summary(fun.y=mean, geom="point", size=2) + theme_bw() +
# ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2)) + coord_cartesian(xlim = c(0, 20)) + stat_summary(fun.y=mean, geom="line", size=1) +
# scale_color_manual(values=c("#CCCCCC", "#FF3300")) + scale_alpha_manual(values=c(0.6, 1))
#
# # ggsave("../reports/vmpfc_comps/mv_vmpfc_vs_all_15.pdf")

# %%
mv_results_all.query('num_features <= 10').groupby('region').apply(lambda x: auc(x['num_features'], x['score_unit'])).max()

# %%
# %%R -w 600 -h 500
# library(ggplot2)
# ggplot(mv_results_all, aes(num_features, score_unit, color=vmpfc)) + theme_bw() + ylab("Explained variance" ) + xlab("Number of topics") +
# theme(axis.title.y = element_text(size = 13, vjust = 0.2))  +
# scale_color_manual(values=c("black", "#FF3300")) + coord_cartesian(xlim = c(0, 25)) + geom_smooth(alpha=0.3)
#
# # + stat_summary(fun.y=mean, geom="line", size=1)
#
# #  + stat_summary(fun.y=mean, geom="point", size=2)
#
# # ggsave("../reports/vmpfc_comps/mv_vmpfc_vs_all_smooth_25.pdf")

# %% [markdown]
# ## Distance plots

# %%
o_clf.feature_importances.shape

# %%
vmpfc_30_rev = vmpfc_30[::-1]

# %%
vmpfc_fis = o_clf.feature_importances[vmpfc_30_rev - 1]

# %%
vmpfc_30-1

# %%
vmpfc_fis = pd.DataFrame(vmpfc_fis)

# %%
vmpfc_fis.index = vmpfc_30_rev

# %%
vmpfc_30_rev

# %%
mpld3.disable_notebook()
sns.corrplot(vmpfc_fis.T, sig_stars=False, sig_corr=False)
