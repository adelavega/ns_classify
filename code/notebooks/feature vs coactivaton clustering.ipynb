# %%
from neurosynth.base.dataset import Dataset
dataset = Dataset.load("../data/datasets/abs_60topics_filt_jul.pkl")

from IPython.html import widgets
# %load_ext rmagic
# %matplotlib inline

import numpy as np
from base import plotting
from base.classifiers import OnevsallContinuous
import base.classifiers.pairwise as pw
import base.classifiers.onevsall as oa
import glob
import pandas as pd
from ggplot import *
from base import tools
from scipy import stats
import itertools
import seaborn as sns
import mpld3
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pylab
import base.classifiers.pairwise as mc
from base.statistics import dcor

mpld3.enable_notebook()
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
clf_a = OnevsallContinuous.load("../results/ward_30_Ridge_abs_topics60_filt/classifier.pkl")

# %%
clf_f = OnevsallContinuous.load("../results/ward_f30_Ridge_abs_topics60_filt/classifier.pkl")

# %%
sns.kdeplot(clf_f.class_score)
sns.kdeplot(clf_a.class_score)

# %%
sns.kdeplot(clf_f.feature_importances.flatten())
sns.kdeplot(clf_a.feature_importances.flatten())

# %%
print clf_f.feature_importances.mean()
print clf_a.feature_importances.mean()
# Out:
# -2.49552045472e-05
# -3.07727586872e-05

# %%
print clf_f.feature_importances.var()
print clf_a.feature_importances.var()
# Out:
# 4.18553491847e-06
# 4.32366203898e-06
